# %%
# %pip install numpy
# %pip install matplotlib

# %%
import os
import sys

from ga_run import (
    run_main_convergence,
    run_sensitivity_analysis,
    run_ga_multiple,
    run_pso_multiple,
    plot_ga_pso_comparison,
    run_pso_convergence,
    run_pso_sensitivity_analysis,
)

# %%
DIR_CONVERGENCE  = "output_convergence"
DIR_SENSITIVITY  = "output_sensitivity"

# %%
filename = "aci_1year"

fitness_all, cappv_all, ebess_all, total_cost_all, cpv_all, cbess_all = run_main_convergence(filename=filename)

run_sensitivity_analysis()

print(f"Convergence outputs → ./{DIR_CONVERGENCE}/")
print(f"Sensitivity outputs → ./{DIR_SENSITIVITY}/")

# %%
pso_filename = "pso_aci_1year"

pso_fitness_all, pso_cappv_all, pso_ebess_all, pso_total_cost_all, pso_cpv_all, pso_cbess_all = \
    run_pso_convergence(filename=pso_filename)

run_pso_sensitivity_analysis()

print(f"PSO Convergence outputs → ./{DIR_CONVERGENCE}/")
print(f"PSO Sensitivity outputs → ./{DIR_SENSITIVITY}/")

# %%
pso_mean_hist, pso_std_hist, pso_stats = run_pso_multiple(filename="pso_aci_final")

# %%
ga_mean_hist, ga_std_hist, ga_stats = run_ga_multiple(filename="ga_aci_final")

plot_ga_pso_comparison(
    ga_mean_hist,  ga_std_hist,  ga_stats,
    pso_mean_hist, pso_std_hist, pso_stats,
    save_path="comparison_ga_vs_pso_multirun_original.jpg",
)

# %%
import importlib, ga_run
importlib.reload(ga_run)

from ga_run import regenerate_comparison_chart

regenerate_comparison_chart(
    ga_multirun_csv  = "output_convergence/ga_multirun_ga_aci_final.csv",
    pso_multirun_csv = "output_pso/pso_multirun_pso_aci_final.csv",
    ga_conv_csv      = "output_convergence/convergence_aci_1year.csv",
    pso_conv_csv     = "pso_convergence_results_pso_aci_final.csv",
    save_path        = "comparison_ga_vs_pso_multirun.jpg",
)
